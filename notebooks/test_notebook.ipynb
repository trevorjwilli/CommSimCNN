# %%
import os
from pathlib import Path
import sys

import torch

rootDir = Path(os.path.abspath(__name__)).parent.parent
sys.path.append(str(rootDir))

from commsimcnn.util import get_conv2d_output_shape

# %%
len(torch.Size([20]))
# Out:
# 1

# %%
get_conv2d_output_shape(x='a2',
                        kernel_size=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 get_conv2d_output_shape(x='a2',
#       2                         kernel_size=3)
#
# File ~/dev/CommSimCNN/commsimcnn/util.py:42, in get_conv2d_output_shape(x, kernel_size, stride, padding, dilation)
#      39 if isinstance(dilation, int):
#      40     dilation = (dilation, dilation)
# ---> 42 h_in = x[-2]
#      43 w_in = x[-1]
#      45 h_out_num = (h_in + 2*padding[0]-dilation[0]*(kernel_size[0]-1)-1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = torch.Size([2])

# %%
assert len(x) >= 2, "Input object must have at least 2 dimensions"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 assert len(x) >= 2, "Input object must have at least 2 dimensions"
#
# AssertionError: Input object must have at least 2 dimensions
